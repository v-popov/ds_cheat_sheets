# %%
import pandas as pd
import numpy as np
from itertools import product

# %% [markdown]
# # Resampling

# %% [markdown]
# ### Data Prep

# %%
dates = pd.date_range(start='2021-01-01', end='2021-01-14', freq='D')
categories1 = ['A', 'B']
data = list(product(categories1, dates))

df = pd.DataFrame(data, columns=['category1', 'date'])

target = np.random.randint(low=0, high=10, size=len(df))
df['target'] = target
df
# Out:
#    category1       date  target
# 0          A 2021-01-01       0
# 1          A 2021-01-02       8
# 2          A 2021-01-03       2
# 3          A 2021-01-04       6
# 4          A 2021-01-05       4
# 5          A 2021-01-06       0
# 6          A 2021-01-07       2
# 7          A 2021-01-08       7
# 8          A 2021-01-09       4
# 9          A 2021-01-10       6
# 10         A 2021-01-11       6
# 11         A 2021-01-12       9
# 12         A 2021-01-13       4
# 13         A 2021-01-14       7
# 14         B 2021-01-01       7
# 15         B 2021-01-02       2
# 16         B 2021-01-03       1
# 17         B 2021-01-04       8
# 18         B 2021-01-05       6
# 19         B 2021-01-06       0
# 20         B 2021-01-07       4
# 21         B 2021-01-08       0
# 22         B 2021-01-09       1
# 23         B 2021-01-10       0
# 24         B 2021-01-11       7
# 25         B 2021-01-12       8
# 26         B 2021-01-13       9
# 27         B 2021-01-14       3

# %% [markdown]
# ### Demo

# %%
df.groupby(['category1']).resample('W', on='date', closed='left').sum()
# Out:
#                       target
# category1 date
# A         2021-01-03       8
#           2021-01-10      25
#           2021-01-17      32
# B         2021-01-03       9
#           2021-01-10      20
#           2021-01-17      27

# %%
df.groupby(['category1']).resample('W', on='date', closed='right').sum()
# Out:
#                       target
# category1 date
# A         2021-01-03      10
#           2021-01-10      29
#           2021-01-17      26
# B         2021-01-03      10
#           2021-01-10      19
#           2021-01-17      27

# %% [markdown]
# # Within Group Lagging (Shifting)

# %% [markdown]
# ### Data Prep

# %%
dates = pd.date_range(start='2021-01-01', end='2021-01-04', freq='D')
categories1 = ['A', 'B']
categories2 = ['CC', 'DD']
data = list(product(categories1, categories2, dates))

# %%
df = pd.DataFrame(data, columns=['category1', 'category2', 'date'])
target = np.random.randint(low=0, high=10, size=len(df))
df['target'] = target
df
# Out:
#    category1 category2       date  target
# 0          A        CC 2021-01-01       8
# 1          A        CC 2021-01-02       9
# 2          A        CC 2021-01-03       4
# 3          A        CC 2021-01-04       2
# 4          A        DD 2021-01-01       2
# 5          A        DD 2021-01-02       7
# 6          A        DD 2021-01-03       9
# 7          A        DD 2021-01-04       8
# 8          B        CC 2021-01-01       8
# 9          B        CC 2021-01-02       0
# 10         B        CC 2021-01-03       8
# 11         B        CC 2021-01-04       8
# 12         B        DD 2021-01-01       5
# 13         B        DD 2021-01-02       9
# 14         B        DD 2021-01-03       6
# 15         B        DD 2021-01-04       3

# %% [markdown]
# ### Demo

# %%
df['shifted_c1'] = df.groupby(['category1'])['target'].shift(1, fill_value=None)
df
# Out:
#    category1 category2       date  target  shifted_c1
# 0          A        CC 2021-01-01       8         NaN
# 1          A        CC 2021-01-02       9         8.0
# 2          A        CC 2021-01-03       4         9.0
# 3          A        CC 2021-01-04       2         4.0
# 4          A        DD 2021-01-01       2         2.0
# 5          A        DD 2021-01-02       7         2.0
# 6          A        DD 2021-01-03       9         7.0
# 7          A        DD 2021-01-04       8         9.0
# 8          B        CC 2021-01-01       8         NaN
# 9          B        CC 2021-01-02       0         8.0
# 10         B        CC 2021-01-03       8         0.0
# 11         B        CC 2021-01-04       8         8.0
# 12         B        DD 2021-01-01       5         8.0
# 13         B        DD 2021-01-02       9         5.0
# 14         B        DD 2021-01-03       6         9.0
# 15         B        DD 2021-01-04       3         6.0

# %%
df['shifted_c1_c2'] = df.groupby(['category1', 'category2'])['target'].shift(1, fill_value=None)
df
# Out:
#    category1 category2       date  target  shifted_c1  shifted_c1_c2
# 0          A        CC 2021-01-01       8         NaN            NaN
# 1          A        CC 2021-01-02       9         8.0            8.0
# 2          A        CC 2021-01-03       4         9.0            9.0
# 3          A        CC 2021-01-04       2         4.0            4.0
# 4          A        DD 2021-01-01       2         2.0            NaN
# 5          A        DD 2021-01-02       7         2.0            2.0
# 6          A        DD 2021-01-03       9         7.0            7.0
# 7          A        DD 2021-01-04       8         9.0            9.0
# 8          B        CC 2021-01-01       8         NaN            NaN
# 9          B        CC 2021-01-02       0         8.0            8.0
# 10         B        CC 2021-01-03       8         0.0            0.0
# 11         B        CC 2021-01-04       8         8.0            8.0
# 12         B        DD 2021-01-01       5         8.0            NaN
# 13         B        DD 2021-01-02       9         5.0            5.0
# 14         B        DD 2021-01-03       6         9.0            9.0
# 15         B        DD 2021-01-04       3         6.0            6.0

# %% [markdown]
# # Within Group Rolling

# %% [markdown]
# ### Data Prep

# %%
dates = pd.date_range(start='2021-01-01', end='2021-01-04', freq='D')
categories1 = ['A', 'B']
categories2 = ['CC', 'DD']
data = list(product(categories1, categories2, dates))

# %%
df = pd.DataFrame(data, columns=['category1', 'category2', 'date'])
target = np.random.randint(low=0, high=10, size=len(df))
df['target'] = target
df
# Out:
#    category1 category2       date  target
# 0          A        CC 2021-01-01       9
# 1          A        CC 2021-01-02       9
# 2          A        CC 2021-01-03       2
# 3          A        CC 2021-01-04       1
# 4          A        DD 2021-01-01       0
# 5          A        DD 2021-01-02       9
# 6          A        DD 2021-01-03       4
# 7          A        DD 2021-01-04       7
# 8          B        CC 2021-01-01       4
# 9          B        CC 2021-01-02       9
# 10         B        CC 2021-01-03       4
# 11         B        CC 2021-01-04       2
# 12         B        DD 2021-01-01       6
# 13         B        DD 2021-01-02       8
# 14         B        DD 2021-01-03       5
# 15         B        DD 2021-01-04       1

# %% [markdown]
# ### Demo

# %%
df.groupby(['category1']).rolling(2)['target'].mean()#.reset_index(drop=True)
# Out:
# category1
# A          0     NaN
#            1     9.0
#            2     5.5
#            3     1.5
#            4     0.5
#            5     4.5
#            6     6.5
#            7     5.5
# B          8     NaN
#            9     6.5
#            10    6.5
#            11    3.0
#            12    4.0
#            13    7.0
#            14    6.5
#            15    3.0
# Name: target, dtype: float64

# %%
df.groupby(['category1', 'category2']).rolling(2)['target'].mean()#.reset_index()
# Out:
# category1  category2
# A          CC         0     NaN
#                       1     9.0
#                       2     5.5
#                       3     1.5
#            DD         4     NaN
#                       5     4.5
#                       6     6.5
#                       7     5.5
# B          CC         8     NaN
#                       9     6.5
#                       10    6.5
#                       11    3.0
#            DD         12    NaN
#                       13    7.0
#                       14    6.5
#                       15    3.0
# Name: target, dtype: float64
